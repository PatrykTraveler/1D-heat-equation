# %%
using Plots
x = collect(50:50:800)
#y = readdlm("/home/traveler/Fortran/errors/kind4.txt")
plot(x,y,seriestype=:scatter,title="Errors for kind = 4")

# %%
y = readdlm("/home/traveler/Fortran/errors/kind8.txt")
plot(x,y,seriestype=:scatter,title="Errors for kind = 8")

# %%
y = readdlm("/home/traveler/Fortran/errors/kind16.txt")
plot(x,y,seriestype=:scatter,title="Errors for kind = 16")
